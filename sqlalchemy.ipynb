# %%
from config import password
from flask import jsonify
import sqlalchemy
from sqlalchemy import create_engine, inspect, func
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session, query


engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/Meteorite_Landings')
conn = engine.connect()

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['landings']

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
Landings = Base.classes.landings

# %%
session = Session(engine)

# %%
results = pd.read_sql("Select * from landings",conn).to_dict()
jsonify(results)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-7decdc54a443> in <module>
#       1 results = pd.read_sql("Select * from landings",conn).to_dict()
# ----> 2 jsonify(results)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\flask\json\__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\werkzeug\local.py in __getattr__(self, name)
#     345         if name == "__members__":
#     346             return dir(self._get_current_object())
# --> 347         return getattr(self._get_current_object(), name)
#     348
#     349     def __setitem__(self, key, value):
#
# ...

# %%
inspector.get_columns("landings")
# Out:
# [{'name': 'name',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'id',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': "nextval('landings_id_seq'::regclass)",
#   'autoincrement': True,
#   'comment': None},
#  {'name': 'nametype',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'classification',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'mass',
#   'type': REAL(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'year',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'latitude',
#   'type': REAL(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
# ...

# %%
landings = pd.read_sql("select * from landings",conn)
landings
# Out:
#              name     id nametype        classification      mass  year  \
# 0          Aachen      1    Valid                    L5      21.0  1880
# 1          Aarhus      2    Valid                    H6     720.0  1951
# 2            Abee      6    Valid                   EH4  107000.0  1952
# 3        Acapulco     10    Valid           Acapulcoite    1914.0  1976
# 4         Achiras    370    Valid                    L6     780.0  1902
# ...           ...    ...      ...                   ...       ...   ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  1990
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  1999
# 45713        Zlin  30410    Valid                    H4       3.3  1939
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  2003
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  1976
#
#        latitude  longitude
# 0       50.7750    6.08333
# 1       56.1833   10.23330
# ...

# %%
last_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first().date
